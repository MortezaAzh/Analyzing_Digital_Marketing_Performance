# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
sample_data = pd.read_excel('data.xlsx',sheet_name='Data1-Daily channel online')
sample_data['ConversionRate'] = sample_data['ConversionRate'].astype(dtype = 'float64')
sample_data['Visitors'] = sample_data['Visitors'].astype(dtype = 'int64')
sample_data['Visits'] = sample_data['Visits'].astype(dtype = 'int64')
sample_data['Pageviews'] = sample_data['Pageviews'].astype(dtype = 'int64')
sample_data['basketstarts'] = sample_data['basketstarts'].astype(dtype = 'int64')
sample_data['bounces'] = sample_data['bounces'].astype(dtype = 'int64')
sample_data['Orders'] = sample_data['Orders'].astype(dtype = 'int64')

# %%
sample_data
# Out:
#           Date  week Channel  Visitors   Visits  Pageviews  basketstarts  \
# 0   2020-01-04     2   email    205383   252475     618396         21676
# 1   2020-01-05     2   email    201819   244251     622376         21040
# 2   2020-01-06     2   email    209620   250845     634738         21207
# 3   2020-01-07     2   email    204276   244068     615821         20965
# 4   2020-01-08     2   email    208057   250561     633602         21595
# ..         ...   ...     ...       ...      ...        ...           ...
# 135 2020-01-27     5   Total    944730  1155151    2903498         99941
# 136 2020-01-28     5   Total    990409  1202564    3040738        102960
# 137 2020-01-29     5   Total    982904  1195032    2987559        104862
# 138 2020-01-30     5   Total   1000173  1198300    3012888        105596
# 139 2020-01-31     5   Total    955738  1150654    2922483        100832
#
#      Errors  bounces  Orders  ConversionRate  BasketStarts_divided_by_Visits  \
# ...

# %%
email = sample_data[sample_data.Channel == 'email']
Natural_search = sample_data[sample_data.Channel == 'Natural search']
Paid_Search = sample_data[sample_data.Channel == 'Paid Search']
Direct = sample_data[sample_data.Channel == 'Direct']
Total = sample_data[sample_data.Channel == 'Total']

# %%
plt.plot(email.Date,email.Orders)
plt.plot(Natural_search.Date,Natural_search.Orders)
plt.plot(Paid_Search.Date,Paid_Search.Orders)
plt.plot(Direct.Date,Direct.Orders)
plt.plot(Total.Date,Total.Orders)
plt.legend(['email','Natural_search','Paid_Search','Direct','Total'],prop={'size': 8},loc = 'upper left')
plt.xlabel('Date')
plt.ylabel('Orders')
plt.gcf().autofmt_xdate()
plt.show()

# %%
plt.plot(email.Date,email.Visits)
plt.plot(Natural_search.Date,Natural_search.Visits)
plt.plot(Paid_Search.Date,Paid_Search.Visits)
plt.plot(Direct.Date,Direct.Visits)
plt.plot(Total.Date,Total.Visits)
plt.legend(['email','Natural_search','Paid_Search','Direct','Total'],prop={'size': 8},loc = 'upper left')
plt.xlabel('Date')
plt.ylabel('Visits')
plt.gcf().autofmt_xdate()
plt.show()

# %%
plt.plot(email.Date,email.Visitors)
plt.plot(Natural_search.Date,Natural_search.Visitors)
plt.plot(Paid_Search.Date,Paid_Search.Visitors)
plt.plot(Direct.Date,Direct.Visits)
plt.plot(Total.Date,Total.Visitors)
plt.legend(['email','Natural_search','Paid_Search','Direct','Total'],prop={'size': 8},loc = 'upper left')
plt.xlabel('Date')
plt.ylabel('Visitors')
plt.gcf().autofmt_xdate()
plt.show()

# %%
plt.plot(email.Date,email.Errors)
plt.plot(Natural_search.Date,Natural_search.Errors)
plt.plot(Paid_Search.Date,Paid_Search.Errors)
plt.plot(Direct.Date,Direct.Errors)
plt.plot(Total.Date,Total.Errors)
plt.legend(['email','Natural_search','Paid_Search','Direct','Total'],prop={'size': 8},loc = 'upper left')
plt.xlabel('Date')
plt.ylabel('Errors')
plt.gcf().autofmt_xdate()
plt.gcf().autofmt_xdate()
plt.gcf().autofmt_xdate()

plt.show()

# %%
plt.plot(email.Date,email.bounces)
plt.plot(Natural_search.Date,Natural_search.bounces)
plt.plot(Paid_Search.Date,Paid_Search.bounces)
plt.plot(Direct.Date,Direct.bounces)
plt.plot(Total.Date,Total.bounces)
plt.legend(['email','Natural_search','Paid_Search','Direct','Total'],loc = 'upper left')
plt.xlabel('Date')
plt.ylabel('bounces')
plt.gcf().autofmt_xdate()
plt.show()

# %%
plt.plot(email.Date,email.basketstarts)
plt.plot(Natural_search.Date,Natural_search.basketstarts)
plt.plot(Paid_Search.Date,Paid_Search.basketstarts)
plt.plot(Direct.Date,Direct.basketstarts)
plt.plot(Total.Date,Total.basketstarts)
plt.legend(['email','Natural_search','Paid_Search','Direct','Total'],loc = 'upper left')
plt.xlabel('Date')
plt.ylabel('basketstarts')
plt.gcf().autofmt_xdate()
plt.show()

# %%
plt.plot(email.Date,email.ConversionRate)
plt.plot(Natural_search.Date,Natural_search.ConversionRate)
plt.plot(Paid_Search.Date,Paid_Search.ConversionRate)
plt.plot(Direct.Date,Direct.ConversionRate)
plt.plot(Total.Date,Total.ConversionRate)
plt.legend(['email','Natural_search','Paid_Search','Direct','Total'],loc = 'lower left')
plt.xlabel('Date')
plt.ylabel('ConversionRate(%)')
plt.gcf().autofmt_xdate()
plt.show()

# %%
plt.plot(email.Date,email.BasketStarts_divided_by_Visits)
plt.plot(Natural_search.Date,Natural_search.BasketStarts_divided_by_Visits)
plt.plot(Paid_Search.Date,Paid_Search.BasketStarts_divided_by_Visits)
plt.plot(Direct.Date,Direct.BasketStarts_divided_by_Visits)
plt.plot(Total.Date,Total.BasketStarts_divided_by_Visits)
plt.legend(['email','Natural_search','Paid_Search','Direct','Total'],loc = 'lower left')
plt.xlabel('Date')
plt.ylabel('BasketStarts_divided_by_Visits(%)')
plt.gcf().autofmt_xdate()
plt.show()

# %%
plt.plot(email.Date,email.ErrorRate)
plt.plot(Natural_search.Date,Natural_search.ErrorRate)
plt.plot(Paid_Search.Date,Paid_Search.ErrorRate)
plt.plot(Direct.Date,Direct.ErrorRate)
plt.plot(Total.Date,Total.ErrorRate)
plt.legend(['email','Natural_search','Paid_Search','Direct','Total'],loc = 'upper left')
plt.xlabel('Date')
plt.ylabel('ErrorRate')
plt.gcf().autofmt_xdate()
plt.show()

# %%
plt.plot(email.Date,email.ErrorRate)
plt.xlabel('Date')
plt.ylabel('ErrorRate-email')
plt.gcf().autofmt_xdate()
plt.show()

# %%
plt.plot(Natural_search.Date,Natural_search.ErrorRate,color="orange")
plt.xlabel('Date')
plt.ylabel('ErrorRate-Natural_search')
plt.gcf().autofmt_xdate()
plt.show()

# %%
plt.plot(Paid_Search.Date,Paid_Search.ErrorRate,color="green")
plt.xlabel('Date')
plt.ylabel('ErrorRate-Paid_Search')
plt.gcf().autofmt_xdate()
plt.show()

# %%
plt.plot(Direct.Date,Direct.ErrorRate,color="r")
plt.xlabel('Date')
plt.ylabel('ErrorRate-Direct')
plt.gcf().autofmt_xdate()
plt.show()

# %%
plt.plot(Total.Date,Total.ErrorRate,color="purple")
plt.xlabel('Date')
plt.ylabel('ErrorRate-Total')
plt.gcf().autofmt_xdate()
plt.show()

# %%
plt.plot(email.Date,email.BounceRate)
plt.plot(Natural_search.Date,Natural_search.BounceRate)
plt.plot(Paid_Search.Date,Paid_Search.BounceRate)
plt.plot(Direct.Date,Direct.BounceRate)
plt.plot(Total.Date,Total.BounceRate)
plt.legend(['email','Natural_search','Paid_Search','Direct','Total'],loc = 'lower left')
plt.xlabel('Date')
plt.ylabel('BounceRate')
plt.gcf().autofmt_xdate()
plt.show()

# %%
plt.plot(email.Date,email.BounceRate,color="b")
plt.xlabel('Date')
plt.ylabel('BounceRate-email')
plt.gcf().autofmt_xdate()
plt.show()

# %%
plt.plot(Natural_search.Date,Natural_search.BounceRate,color="orange")
plt.xlabel('Date')
plt.ylabel('BounceRate-Natural_search')
plt.gcf().autofmt_xdate()
plt.show()

# %%
plt.plot(Paid_Search.Date,Paid_Search.BounceRate,color="green")
plt.xlabel('Date')
plt.ylabel('BounceRate-Paid_Search')
plt.gcf().autofmt_xdate()
plt.show()

# %%
plt.plot(Direct.Date,Direct.BounceRate,color="r")
plt.xlabel('Date')
plt.ylabel('BounceRate-Direct')
plt.gcf().autofmt_xdate()
plt.show()

# %%
plt.plot(Total.Date,Total.BounceRate,color="purple")
plt.xlabel('Date')
plt.ylabel('BounceRate-Total')
plt.gcf().autofmt_xdate()
plt.show()

# %%
plt.plot(email.Date,email.BasketStarts_divided_by_Visits,color="b")
plt.xlabel('Date')
plt.ylabel('BasketStarts_divided_by_Visits-email(%)')
plt.gcf().autofmt_xdate()
plt.show()

# %%
plt.plot(Natural_search.Date,Natural_search.BasketStarts_divided_by_Visits,color="orange")
plt.xlabel('Date')
plt.ylabel('BasketStarts_divided_by_Visits-Natural_search(%)')
plt.gcf().autofmt_xdate()
plt.show()

# %%
plt.plot(Paid_Search.Date,Paid_Search.BasketStarts_divided_by_Visits,color="green")
plt.xlabel('Date')
plt.ylabel('BasketStarts_divided_by_Visits-Paid_Search(%)')
plt.gcf().autofmt_xdate()
plt.show()

# %%
plt.plot(Direct.Date,Direct.BasketStarts_divided_by_Visits,color="r")
plt.xlabel('Date')
plt.ylabel('BasketStarts_divided_by_Visits-Direct(%)')
plt.gcf().autofmt_xdate()
plt.show()

# %%
plt.plot(Total.Date,Total.BasketStarts_divided_by_Visits,color="purple")
plt.xlabel('Date')
plt.ylabel('BasketStarts_divided_by_Visits-Total(%)')
plt.gcf().autofmt_xdate()
plt.show()

# %%
sample_data_week = pd.read_excel('data.xlsx',sheet_name='Data2-Weekly channel order info')

# %%
sample_data_week
# Out:
#            Channel WeekStartDate         Orders       Revenue
# 0           Direct    2020-01-04  185954.304969  1.850245e+06
# 1           Direct    2020-01-11  192940.184190  1.921684e+06
# 2           Direct    2020-01-18  188759.517505  1.861169e+06
# 3           Direct    2020-01-25  137154.279572  1.381144e+06
# 4            email    2020-01-04   90716.865971  6.356531e+05
# 5            email    2020-01-11   89420.693570  6.271967e+05
# 6            email    2020-01-18   91477.443212  6.512279e+05
# 7            email    2020-01-25   66787.022400  4.600290e+05
# 8   Natural search    2020-01-04   82525.836303  1.007145e+06
# 9   Natural search    2020-01-11   87691.904506  1.035466e+06
# 10  Natural search    2020-01-18   96398.297931  1.153309e+06
# 11  Natural search    2020-01-25   71480.889127  8.431886e+05
# 12     Paid Search    2020-01-04   43684.491739  6.572332e+05
# 13     Paid Search    2020-01-11   40183.502254  6.454030e+05
# ...

# %%
email = sample_data_week[sample_data_week.Channel == 'email']
Natural_search = sample_data_week[sample_data_week.Channel == 'Natural search']
Paid_Search = sample_data_week[sample_data_week.Channel == 'Paid Search']
Direct = sample_data_week[sample_data_week.Channel == 'Direct']
Total = sample_data_week[sample_data_week.Channel == 'Total']

# %%
plt.plot(email.WeekStartDate,email.Orders)
plt.plot(Natural_search.WeekStartDate,Natural_search.Orders)
plt.plot(Paid_Search.WeekStartDate,Paid_Search.Orders)
plt.plot(Direct.WeekStartDate,Direct.Orders)
plt.plot(Total.WeekStartDate,Total.Orders)
plt.legend(['email','Natural_search','Paid_Search','Direct','Total'],prop={'size': 8},loc = 'upper left')
plt.xlabel('WeekStartDate')
plt.ylabel('Orders')
plt.gcf().autofmt_xdate()
plt.show()

# %%
plt.plot(email.WeekStartDate,email.Revenue)
plt.plot(Natural_search.WeekStartDate,Natural_search.Revenue)
plt.plot(Paid_Search.WeekStartDate,Paid_Search.Revenue)
plt.plot(Direct.WeekStartDate,Direct.Revenue)
plt.plot(Total.WeekStartDate,Total.Revenue)
plt.legend(['email','Natural_search','Paid_Search','Direct','Total'],prop={'size': 8},loc = 'upper left')
plt.xlabel('WeekStartDate')
plt.ylabel('Revenue')
plt.gcf().autofmt_xdate()
plt.show()
